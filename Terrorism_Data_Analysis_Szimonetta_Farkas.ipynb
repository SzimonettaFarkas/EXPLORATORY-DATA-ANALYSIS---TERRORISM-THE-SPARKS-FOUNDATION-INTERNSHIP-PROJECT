# %% [markdown]
# **EXPLORATORY DATA ANALYSIS - TERRORISM , THE SPARKS FOUNDATION INTERNSHIP PROJECT**

# %% [markdown]
# **made by Szimonetta Farkas**

# %% [markdown]
# **Objective: Perform Exploratory Data Analysis on dataset 'Global Terrorism'**

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the Dataset
data = pd.read_csv(r'E:\Data_Science\INTERNSHIP\The_Sparks_Foundation\4_Terrorism_Data\Global Terrorism - START data\terrorism_dataset.csv',
                   encoding = "ISO-8859-1")

# %%
# Discovering the Dataset
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country
# 0  197000000001   1970       7     2        NaN         0        NaN       58  \
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS  \
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution
# 181686  201712310022   2017      12    31        NaN         0        NaN  \
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes
# 181686      182      Somalia      11  ...      NaN  \
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...  \
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
data.size
# Out:
# 24528285

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Creating a Copy of the Dataset
data1 = data.copy()
data1.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country
# 0  197000000001   1970       7     2        NaN         0        NaN       58  \
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS  \
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# Data Preprocessing, Cleaning
# Looking for Missing Values
data1.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Percentage of Missing Values
null_sum = (data1.isnull().sum()/len(data))*100
null_sum
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %%
# Sorting Columns According to the Percentage of Missing Values
percent_null=null_sum.sort_values(ascending=False)
percent_null
# Out:
# gsubname3           99.988992
# weapsubtype4_txt    99.961473
# weapsubtype4        99.961473
# weaptype4           99.959822
# weaptype4_txt       99.959822
#                       ...
# suicide              0.000000
# success              0.000000
# crit3                0.000000
# property             0.000000
# eventid              0.000000
# Length: 135, dtype: float64

# %%
# Columns with more than 50% Mising Values
more_than_50 = percent_null[percent_null>=50]
more_than_50
# Out:
# gsubname3           99.988992
# weapsubtype4_txt    99.961473
# weapsubtype4        99.961473
# weaptype4           99.959822
# weaptype4_txt       99.959822
#                       ...
# propcomment         68.100236
# propextent          64.739585
# propextent_txt      64.739585
# scite2              57.657231
# ransom              57.410659
# Length: 77, dtype: float64

# %%
# Columns with less than 50% Missing Values
less_than_50=percent_null[~percent_null.isin(more_than_50)]
less_null=less_than_50.index.to_list()
print(len(less_null))
print(less_null)
# Out:
# 58
# ['nperps', 'nperpcap', 'nwoundte', 'weapdetail', 'nkillter', 'scite1', 'summary', 'claimed', 'nwoundus', 'nkillus', 'corp1', 'weapsubtype1', 'weapsubtype1_txt', 'nwound', 'targsubtype1', 'targsubtype1_txt', 'nkill', 'longitude', 'latitude', 'natlty1', 'natlty1_txt', 'target1', 'city', 'provstate', 'guncertain1', 'ishostkid', 'specificity', 'doubtterr', 'multiple', 'crit1', 'iyear', 'iday', 'imonth', 'targtype1_txt', 'gname', 'individual', 'dbsource', 'country', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY', 'extended', 'region_txt', 'country_txt', 'region', 'crit2', 'targtype1', 'weaptype1', 'weaptype1_txt', 'attacktype1_txt', 'attacktype1', 'vicinity', 'suicide', 'success', 'crit3', 'property', 'eventid']

# %%
dataset = data1[less_null]
dataset.head()
# Out:
#    nperps  nperpcap  nwoundte  weapdetail  nkillter scite1 summary  claimed
# 0     NaN       NaN       NaN         NaN       NaN    NaN     NaN      NaN  \
# 1     7.0       NaN       NaN         NaN       NaN    NaN     NaN      NaN
# 2     NaN       NaN       NaN         NaN       NaN    NaN     NaN      NaN
# 3     NaN       NaN       NaN   Explosive       NaN    NaN     NaN      NaN
# 4     NaN       NaN       NaN  Incendiary       NaN    NaN     NaN      NaN
#
#    nwoundus  nkillus  ... weaptype1  weaptype1_txt
# 0       NaN      NaN  ...        13        Unknown  \
# 1       NaN      NaN  ...        13        Unknown
# 2       NaN      NaN  ...        13        Unknown
# 3       NaN      NaN  ...         6     Explosives
# 4       NaN      NaN  ...         8     Incendiary
#
#                   attacktype1_txt  attacktype1  vicinity suicide  success
# 0                   Assassination            1         0       0        1  \
# ...

# %%
checking = dataset.columns.to_list()
selected_columns=['eventid', 'iyear', 'imonth', 'iday','country_txt','region_txt','city','multiple', 'success', 
                    'suicide', 'attacktype1_txt', 'targtype1_txt',  'targsubtype1_txt', 'corp1', 
                    'target1', 'natlty1_txt', 'weaptype1_txt','nkill','nwoundus', 'claimed', 'individual', 'INT_LOG', 
                    'doubtterr', 'INT_MISC', 'specificity','gname', 'ishostkid', 'INT_ANY', 'guncertain1', 'provstate']

# %%
len(checking)-len(selected_columns)
# Out:
# 28

# %%
print(list((set(checking)) - (set(selected_columns))))
# Out:
# ['weapdetail', 'weapsubtype1_txt', 'nkillter', 'summary', 'scite1', 'property', 'nperps', 'nkillus', 'dbsource', 'natlty1', 'nwoundte', 'country', 'extended', 'nwound', 'weapsubtype1', 'latitude', 'longitude', 'targsubtype1', 'targtype1', 'crit2', 'vicinity', 'region', 'INT_IDEO', 'crit3', 'crit1', 'attacktype1', 'nperpcap', 'weaptype1']

# %%
df=data1[selected_columns]
df.T
# Out:
#                                        0
# eventid                          197000000001  \
# iyear                                    1970
# imonth                                      7
# iday                                        2
# country_txt                Dominican Republic
# region_txt        Central America & Caribbean
# city                            Santo Domingo
# multiple                                  0.0
# success                                     1
# suicide                                     0
# attacktype1_txt                 Assassination
# targtype1_txt     Private Citizens & Property
# targsubtype1_txt               Named Civilian
# corp1                                     NaN
# target1                          Julio Guzman
# natlty1_txt                Dominican Republic
# weaptype1_txt                         Unknown
# nkill                                     1.0
# nwoundus                                  NaN
# ...

# %%
# Looking for Missing Values in the Current Dataset
df.isna().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# country_txt             0
# region_txt              0
# city                  435
# multiple                1
# success                 0
# suicide                 0
# attacktype1_txt         0
# targtype1_txt           0
# targsubtype1_txt    10373
# corp1               42552
# target1               638
# natlty1_txt          1559
# weaptype1_txt           0
# nkill               10313
# nwoundus            64702
# claimed             66120
# individual              0
# INT_LOG                 0
# doubtterr               1
# INT_MISC                0
# specificity             6
# gname                   0
# ishostkid             178
# INT_ANY                 0
# guncertain1           380
# provstate             421
# dtype: int64

# %%
# Percentage of Missing Values
(df.isnull().sum()/len(df))*100
# Out:
# eventid              0.000000
# iyear                0.000000
# imonth               0.000000
# iday                 0.000000
# country_txt          0.000000
# region_txt           0.000000
# city                 0.239417
# multiple             0.000550
# success              0.000000
# suicide              0.000000
# attacktype1_txt      0.000000
# targtype1_txt        0.000000
# targsubtype1_txt     5.709144
# corp1               23.419982
# target1              0.351146
# natlty1_txt          0.858050
# weaptype1_txt        0.000000
# nkill                5.676120
# nwoundus            35.611010
# claimed             36.391456
# individual           0.000000
# INT_LOG              0.000000
# doubtterr            0.000550
# INT_MISC             0.000000
# specificity          0.003302
# gname                0.000000
# ishostkid            0.097969
# INT_ANY              0.000000
# guncertain1          0.209146
# provstate            0.231712
# dtype: float64

# %%
# Structure Information, Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   iyear             181691 non-null  int64
#  2   imonth            181691 non-null  int64
#  3   iday              181691 non-null  int64
#  4   country_txt       181691 non-null  object
#  5   region_txt        181691 non-null  object
#  6   city              181256 non-null  object
#  7   multiple          181690 non-null  float64
#  8   success           181691 non-null  int64
#  9   suicide           181691 non-null  int64
#  10  attacktype1_txt   181691 non-null  object
#  11  targtype1_txt     181691 non-null  object
#  12  targsubtype1_txt  171318 non-null  object
#  13  corp1             139139 non-null  object
#  14  target1           181053 non-null  object
#  15  natlty1_txt       180132 non-null  object
# ...

# %%
# Exploratory Data Analysis
# Attack per Year
attack_per_year=df['iyear'].value_counts()
ax=plt.rcParams['figure.figsize'] = 22,8.27
ax=sns.countplot(x='iyear',data=df, color = 'blue')
ax.set_xlabel('Year')
plt.xticks(rotation = 45)
ax.set_ylabel('Number of Terrorist Attack')
ax.set_title('Number of Terrorist Attacks Per Year')
# Out:
# Text(0.5, 1.0, 'Number of Terrorist Attacks Per Year')

# %%
# Top 15 Most Attacked Countries
ax=plt.rcParams['figure.figsize'] = 22,8.27
ax=sns.countplot(x='country_txt',data=df,order = df['country_txt'].value_counts().index[:15], color  = 'blue')
ax.set_xlabel('Country')
plt.xticks(rotation = 75)
ax.set_ylabel('Number of Terrorist Attacks')
ax.set_title('Top 15 Most Attacked Countries')
# Out:
# Text(0.5, 1.0, 'Top 15 Most Attacked Countries')

# %%
# Number of Attacks per Region
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.countplot(x='region_txt',data=df,order = df['region_txt'].value_counts().index, color = 'green')
ax.set_xlabel('Region',fontsize=18)
plt.xticks(rotation = 75)
ax.set_ylabel('Number of Terrorist Attacks')
ax.set_title('Number of Attacks per Region')
# Out:
# Text(0.5, 1.0, 'Number of Attacks per Region')

# %%
# Top 5 Most Frequently Used Weapon Types
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.countplot(x='weaptype1_txt',data=df,order = df['weaptype1_txt'].value_counts().index[:5], color = 'green')
ax.set_xlabel('Weapon Type')
plt.xticks(rotation = 75)
ax.set_ylabel('Number of Attacks')
ax.set_title('Top 5 Most Frequently Used Weapon Types')
# Out:
# Text(0.5, 1.0, 'Top 5 Most Frequently Used Weapon Types')

# %%
# Top 5 Most Frequent Type of Attacks
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.countplot(x='attacktype1_txt',data=df,order = df['attacktype1_txt'].value_counts().index[:5], color = 'red')
ax.set_xlabel('Type of Attack')
plt.xticks(rotation = 75)
ax.set_ylabel('Number of Attacks')
ax.set_title('Top 5 Most Frequent Type of Attacks')
# Out:
# Text(0.5, 1.0, 'Top 5 Most Frequent Type of Attacks')

# %%
# Top 10 Most Frequents Targets
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.countplot(x='targtype1_txt',data=df,order = df['targtype1_txt'].value_counts().index[:10], color = 'red')
ax.set_xlabel('Type of Targets')
plt.xticks(rotation = 75)
ax.set_ylabel('Number of Attacks')
ax.set_title('Top 10 Most Frequents Targets')
# Out:
# Text(0.5, 1.0, 'Top 10 Most Frequents Targets')

# %%
# Top 15 Terrorist Organizations Made Most Number of Attacks
ax=plt.rcParams['figure.figsize'] = 16,12
ax=sns.countplot(y='gname',data=df,order = df['gname'].value_counts().index[1:15], color = 'black')
ax.set_ylabel('Terrorist Organizations')
# plt.yticks(rotation = 75)
ax.set_xlabel('Number of Attacks')
ax.set_title('Top 15 Terrorist Organizations Made Most Number of Attacks')
# Out:
# Text(0.5, 1.0, 'Top 15 Terrorist Organizations Made Most Number of Attacks')

# %%
# Ratio of Successful Terrorist Attacks
colors = ['red', 'green']
ax=df['success'].value_counts().plot(kind='pie', colors = colors)
ax.set_title('Ratio of Successful Terrorist Attacks')
# Out:
# Text(0.5, 1.0, 'Ratio of Successful Terrorist Attacks')

# %%
# Performance of Countries Against Terrorist Attacks
# Top 10 Countries with the Best Performance Against Terrorist Attacks (More than 5 Attacks)
success_country=df.groupby('country_txt').agg({'eventid':'count','success':'sum'}).reset_index()
success_country.columns=['Country','Total_Attacks','Attack_Success']
success_country['Attack_Failed']=success_country['Total_Attacks']-success_country['Attack_Success']
success_country['Failure_Rate_Attack']=(success_country['Attack_Failed']/success_country['Total_Attacks'])*100
success_country['Success_Rate_Attack']=(success_country['Attack_Success']/success_country['Total_Attacks'])*100
success_country=success_country.round(2)

able_stop_terror_attack=success_country[success_country['Total_Attacks']>=5].sort_values('Failure_Rate_Attack',
                                                                                         ascending=False )[:10]
plot_able_stop_terror_attack=able_stop_terror_attack.loc[:,['Country','Failure_Rate_Attack']]
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.barplot(x='Country',y='Failure_Rate_Attack',data=plot_able_stop_terror_attack, color = 'black')
ax.set_xlabel('Countries')
plt.xticks(rotation = 75)
ax.set_ylabel('Ratio of Failure of Terror Attacks')
ax.set_title("Top 10 Countries with the Best Performance Against Terrorist Attacks")
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with the Best Performance Against Terrorist Attacks')

# %%
# Top 10 Countries with the Worst Performance Against Terrorist Attacks (More than 5 Attacks)
unable_stop_terror_attack=success_country[success_country['Total_Attacks']>=5].sort_values('Success_Rate_Attack'
                                                                                           ,ascending=False )[:10]
plot_unable_stop_terror_attack=unable_stop_terror_attack.loc[:,['Country','Success_Rate_Attack','Total_Attacks']]
ax=plt.rcParams['figure.figsize'] = 16,8.27
ax=sns.barplot(x='Country',y='Success_Rate_Attack',data=plot_unable_stop_terror_attack, color = 'red')
ax.set_xlabel('Countries')
plt.xticks(rotation = 75)
ax.set_ylabel('Ratio of Success of Terror Attack')
ax.set_title('Top 10 Countries with the Worst Performance Against Terrorist Attacks ')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with the Worst Performance Against Terrorist Attacks ')

# %%
# Terrorist Attack Trends
# Weapon Type Trends
attack_per_year=df.groupby(['iyear','targtype1_txt','target1','success','weaptype1_txt',
                              'gname'])['eventid'].count().to_frame(name = 'Total_Attacks').reset_index()
ax = sns.relplot(col="weaptype1_txt", y="Total_Attacks",col_wrap=4, hue='weaptype1_txt',x="iyear"
                 ,kind='line', ci=None ,data=attack_per_year, height=3, aspect=1.5, legend=False)

# %%
# Target Type Trends
ax = sns.relplot(col="targtype1_txt", y="Total_Attacks",col_wrap=5,
                 hue='targtype1_txt',x="iyear",kind='line', ci=None ,data=attack_per_year, height=3, aspect=1.5, legend=False)

# %%
# Trend of Successful/Unsuccessful Terrorist Attacks
ax = sns.lineplot(x="iyear", y="Total_Attacks", hue='success', ci=None ,data=attack_per_year)
ax.tick_params(rotation=45)
